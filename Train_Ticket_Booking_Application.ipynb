# %%
# !pip install sqlalchemy==1.3.23
# !pip install ipython-sql
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 51.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.23-cp310-cp310-linux_x86_64.whl size=1250456 sha256=1a8420f0f9cc25ee75a58793484937782c419b80091216f73201e8266f5e8847
#   Stored in directory: /root/.cache/pip/wheels/6b/bd/5f/b63dc9976fc54a34ac2019fdbef4eb6a15aef4958298ce4b55
# Successfully built sqlalchemy
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.23
#     Uninstalling SQLAlchemy-2.0.23:
#       Successfully uninstalled SQLAlchemy-2.0.23
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.13.0 requires sqlalchemy<3.0dev,>=1.4, but you have sqlalchemy 1.3.23 which is incompatible.
# ...

# %%
# %load_ext sql

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %sql sqlite:////content/drive/MyDrive/DB/db.db

# %%
# %%sql
# SELECT * FROM Booked;
# Out:
#  * sqlite:////content/drive/MyDrive/DB/db.db
# Done.
# [(264816896, 3, 'Premium', 'Booked'),
#  (240471168, 2, 'General', 'Booked'),
#  (285200976, 4, 'Premium', 'Booked'),
#  (285200976, 2, 'Premium', 'Booked'),
#  (317434088, 2, 'Premium', 'Booked'),
#  (310908858, 2, 'General', 'Booked'),
#  (322273872, 2, 'General', 'Booked'),
#  (256558303, 3, 'Premium', 'WaitL'),
#  (302548590, 2, 'General', 'WaitL'),
#  (284965676, 3, 'Premium', 'WaitL'),
#  (277292710, 3, 'General', 'WaitL'),
#  (331160133, 3, 'General', 'WaitL'),
#  (331293204, 3, 'General', 'WaitL'),
#  (290123298, 3, 'General', 'WaitL'),
#  (286411536, 4, 'Premium', 'Booked'),
#  (294860856, 4, 'Premium', 'Booked'),
#  (317434088, 4, 'Premium', 'Booked'),
#  (310908858, 4, 'Premium', 'Booked'),
#  (322273872, 4, 'Premium', 'Booked'),
#  (256558303, 4, 'Premium', 'Booked'),
#  (302548590, 4, 'Premium', 'Booked'),
#  (284965676, 4, 'General', 'Booked'),
#  (277292710, 4, 'General', 'Booked'),
# ...

# %%
import sqlite3
conn = sqlite3.connect('//content/drive/MyDrive/DB/db.db')
cursor = conn.cursor()
booked = cursor.execute(''' SELECT * FROM Booked ''')
passenger = cursor.execute(''' SELECT * FROM Passenger ''')
train = cursor.execute('''select * from Train;''')
status = cursor.execute('''select * from Train_Status;''')
#SELECT name FROM sqlite_master WHERE type='table'
res_booked = booked.fetchall()
for row in res_booked:
  print(row)
print()
# Out:
# ('2022-02-19', 'Orient Express', 10, 10, 0, 0)
# ('2022-02-20', 'Flying Scottsman', 8, 5, 2, 5)
# ('2022-02-21', 'Maharaja Express', 7, 6, 3, 4)
# ('2022-02-21', 'Golden Chariot', 6, 3, 4, 7)
# ('2022-02-22', 'Golden Arrow', 8, 7, 2, 3)
# ('2022-03-10', 'Golden Arrow', 8, 5, 2, 5)
# ('2022-02-21', 'Maharaja Express', 7, 6, 3, 4)
# ('2022-02-21', 'Flying Scottsman', 5, 5, 5, 5)

# %%
# !pip install ipywidgets

# %%
import sqlite3
import pandas as pd
import ipywidgets as widgets
from IPython.display import display

# Connect to the SQLite database
conn = sqlite3.connect('/content/drive/MyDrive/DB/db.db')

# Fetch all tables in the database
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# Create a dropdown for selecting a table
table_dropdown = widgets.Dropdown(
    options=[table[0] for table in tables],
    value=tables[0][0],
    description='Select Table:'
)

# Display the table dropdown
display(table_dropdown)

# Input fields for additional parameters
# (e.g., if you need to input values for a WHERE clause)
# Example: start_date_input = widgets.Text(description='Start Date:')
# Display the input fields as needed

# Function to fetch and display query results based on user input
def execute_query(change):
    selected_table = table_dropdown.value

    # Customize the query based on user input
    query = f"SELECT * FROM {selected_table};"

    # Add WHERE clause based on additional input fields if needed
    # Example: query += f" WHERE start_date >= '{start_date_input.value}'"

    # Execute the query and display the result
    result = pd.read_sql_query(query, conn)
    display(result)

# Register the function to be called when the dropdown value changes
table_dropdown.observe(execute_query, names='value')

# Trigger the initial query execution to display the default table
execute_query(None)
# Out:
# Dropdown(description='Select Table:', options=('Booked', 'Passenger', 'Train', 'Train_Status'), value='Booked'…
#     Passanger_ssn  Train_Number Ticket_Type  Status
# 0       264816896             3     Premium  Booked
# 1       240471168             2     General  Booked
# 2       285200976             4     Premium  Booked
# 3       285200976             2     Premium  Booked
# 4       317434088             2     Premium  Booked
# 5       310908858             2     General  Booked
# 6       322273872             2     General  Booked
# 7       256558303             3     Premium   WaitL
# 8       302548590             2     General   WaitL
# 9       284965676             3     Premium   WaitL
# 10      277292710             3     General   WaitL
# 11      331160133             3     General   WaitL
# 12      331293204             3     General   WaitL
# 13      290123298             3     General   WaitL
# 14      286411536             4     Premium  Booked
# ...

# %%
import sqlite3
import pandas as pd
import ipywidgets as widgets
from IPython.display import display

# Connect to the SQLite database
conn = sqlite3.connect('/content/drive/MyDrive/DB/db.db')

# Define a dictionary to map options to queries
queries_dict = {
    'Display Booking Details': '''
        SELECT T.TrainName, T.TrainNumber, T.SourceStation, T.DestinationStation
        FROM Train AS T
        JOIN Booked AS B ON T.TrainNumber = B.Train_Number
        JOIN Passenger AS P ON B.Passanger_ssn = P.SSN
        WHERE P.first_name=? AND P.last_name=?;
    '''
    # Add other queries as needed
}

# Create a dropdown for selecting an option
options_dropdown = widgets.Dropdown(
    options=list(queries_dict.keys()),
    value='Display Booking Details',
    description='Select Option:'
)

# Display the dropdown
display(options_dropdown)

# Function to execute queries based on the selected option
def execute_query(change):
    selected_option = options_dropdown.value
    query = queries_dict.get(selected_option, 'SELECT * FROM Train;')  # Default query if option not found

    if selected_option == 'Display Booking Details':
        # Input fields for additional parameters
        first_name_input = widgets.Text(description='First Name:')
        last_name_input = widgets.Text(description='Last Name:')
        display(first_name_input, last_name_input)

        # Function to be called after submitting inputs
        def on_submit_inputs(btn):
            # Execute the query and display the result
            cursor = conn.cursor()
            cursor.execute(query, (first_name_input.value, last_name_input.value))
            result = pd.DataFrame(cursor.fetchall(), columns=['TrainName', 'TrainNumber', 'SourceStation', 'DestinationStation'])
            display(result)

        # Create a button to submit the inputs
        submit_button = widgets.Button(description="Submit")
        submit_button.on_click(on_submit_inputs)
        display(submit_button)

# Register the function to be called when the dropdown value changes
options_dropdown.observe(execute_query, names='value')

# Trigger the initial query execution to display the default result
execute_query(None)
# Out:
# Dropdown(description='Select Option:', options=('Display Booking Details',), value='Display Booking Details')
# Text(value='', description='First Name:')
# Text(value='', description='Last Name:')
# Button(description='Submit', style=ButtonStyle())
#           TrainName  TrainNumber SourceStation DestinationStation
# 0  Flying Scottsman            2     Edinburgh             London
# 1    Golden Chariot            4     Bangalore                Goa

# %%
import sqlite3
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, clear_output

class QueryExecutor:
    def __init__(self, conn):
        self.conn = conn
        self.options_dict = {
            'Display Booking Details': '''
                select T.TrainName, T.TrainNumber, T.SourceStation, T.DestinationStation FROM Train as T JOIN
                Booked as B on T.TrainNumber = B.Train_Number JOIN
                Passenger as P on B.Passanger_ssn = P.SSN
                where P.first_name=? and P.last_name=?;
            ''',
            'Display Trains on Selected Date': '''
                select P.first_name, P.last_name, T.TrainName, T.TrainNumber, B.Status FROM Train as T JOIN
                Booked as B on T.TrainNumber = B.Train_Number JOIN
                Passenger as P on B.Passanger_ssn = P.SSN JOIN
                Train_Status as TS on TS.TrainName = T.TrainName
                where TrainDate=? and B.Status = "Booked";
            '''
            # Add other queries as needed
        }

        self.options_dropdown = widgets.Dropdown(
            options=list(self.options_dict.keys()),
            value='Display Booking Details',
            description='Select Option:'
        )


        # Display the initial widgets
        display(self.options_dropdown)
        self.execute_query(None)

    def execute_query(self, change):
        selected_option = self.options_dropdown.value
        query = self.options_dict.get(selected_option, 'SELECT * FROM Train;')  # Default query if option not found

        if selected_option == 'Display Booking Details':
            # Display input fields for booking details
            self.first_name_input = widgets.Text(description='First Name:')
            self.last_name_input = widgets.Text(description='Last Name:')
            self.submit_button = widgets.Button(description="Submit")
            self.submit_button.on_click(self.on_submit_inputs)
            display(self.first_name_input, self.last_name_input, self.submit_button)
        elif selected_option == 'Display Trains on Selected Date':
            # Display input field for selected date
            self.date_input = widgets.Text(description='Date (YYYY-MM-DD):')
            self.submit_button = widgets.Button(description="Submit")
            self.submit_button.on_click(self.on_submit_inputs)
            display(self.date_input, self.submit_button)


    def on_submit_inputs(self, btn):
        clear_output(wait=True)
        selected_option = self.options_dropdown.value
        query = self.options_dict.get(selected_option, 'SELECT * FROM Train;')  # Default query if option not found

        # Execute the query based on the selected option
        cursor = self.conn.cursor()

        if selected_option == 'Display Booking Details':
            clear_output(wait=True)
            columns = ['Train Name', 'Train Number', 'Status', 'Train Date']
            cursor.execute(query, (self.first_name_input.value, self.last_name_input.value))
        elif selected_option == 'Display Trains on Selected Date':
            clear_output(wait=True)
            columns = ['First Name', 'Last Name', 'Train Name', 'Train Number', 'Status']
            cursor.execute(query, (self.date_input.value,))

        # Display the result
        result = pd.DataFrame(cursor.fetchall(), columns=columns)
        display(result)

# Connect to the SQLite database
conn = sqlite3.connect('/content/drive/MyDrive/DB/db.db')

# Instantiate the QueryExecutor class
query_executor = QueryExecutor(conn)

# Register the function to be called when the dropdown value changes
query_executor.options_dropdown.observe(query_executor.execute_query, names='value')
# Out:
#    First Name  Last Name        Train Name  Train Number  Status
# 0   Josephine    Darakjy  Flying Scottsman             2  Booked
# 1         Art     Venere    Golden Chariot             4  Booked
# 2         Art     Venere  Flying Scottsman             2  Booked
# 3    Fletcher      Flosi  Flying Scottsman             2  Booked
# 4        Sage     Wieser  Flying Scottsman             2  Booked
# 5        Kris    Marrier  Flying Scottsman             2  Booked
# 6      Gladys        Rim    Golden Chariot             4  Booked
# 7        Yuki    Whobrey    Golden Chariot             4  Booked
# 8    Fletcher      Flosi    Golden Chariot             4  Booked
# 9        Sage     Wieser    Golden Chariot             4  Booked
# 10       Kris    Marrier    Golden Chariot             4  Booked
# 11      Minna     Amigon    Golden Chariot             4  Booked
# 12       Abel    Maclead    Golden Chariot             4  Booked
# ...

# %%
import sqlite3
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, clear_output

class QueryExecutor:
    def __init__(self, conn):
        self.conn = conn
        self.options_dict = {
            'Select optn': '''
            ''',
            'Display Booking Details': '''
                SELECT T.TrainName, T.TrainNumber, T.SourceStation, T.DestinationStation
                FROM Train as T
                JOIN Booked as B ON T.TrainNumber = B.Train_Number
                JOIN Passenger as P ON B.Passanger_ssn = P.SSN
                WHERE P.first_name=? AND P.last_name=?;
            ''',
            'Display Trains on Selected Date': '''
                SELECT P.first_name, P.last_name, T.TrainName, T.TrainNumber, B.Status
                FROM Train as T
                JOIN Booked as B ON T.TrainNumber = B.Train_Number
                JOIN Passenger as P ON B.Passanger_ssn = P.SSN
                JOIN Train_Status as TS ON TS.TrainName = T.TrainName
                WHERE TS.TrainDate=? AND B.Status = "Booked";
            '''
            # Add other queries as needed
        }

        self.menu_options = widgets.Dropdown(
            options=list(self.options_dict.keys()),
            value='Select optn',
            description='Select Option:'
        )

        self.exit_button = widgets.Button(description='Exit')

        self.menu_options.observe(self.on_option_selected, names='value')
        self.exit_button.on_click(self.exit_loop)

        # Initialize input widgets
        self.first_name_input = widgets.Text(description='First Name:')
        self.last_name_input = widgets.Text(description='Last Name:')
        self.date_input = widgets.Text(description='Date (YYYY-MM-DD):')
        self.submit_button = widgets.Button(description="Submit")
        self.submit_button.on_click(self.on_submit_inputs)

        # Display the initial widgets
        display(self.menu_options, self.exit_button)

    def on_option_selected(self, change):
        selected_option = change['new']

        if selected_option == 'Display Booking Details':
            display(self.first_name_input, self.last_name_input, self.submit_button)
        elif selected_option == 'Display Trains on Selected Date':
            display(self.date_input, self.submit_button)
        elif selected_option == 'Select optn':
            pass

    def on_submit_inputs(self, btn):
        selected_option = self.menu_options.value
        query = self.options_dict.get(selected_option, 'SELECT * FROM Train;')  # Default query if option not found

        # Execute the query based on the selected option
        cursor = self.conn.cursor()

        if selected_option == 'Display Booking Details':
            self.columns = ['Train Name', 'Train Number', 'Status', 'Train Date']
            cursor.execute(query, (self.first_name_input.value, self.last_name_input.value))
        elif selected_option == 'Display Trains on Selected Date':
            self.columns = ['First Name', 'Last Name', 'Train Name', 'Train Number', 'Status']
            cursor.execute(query, (self.date_input.value,))

        # Display the result
        result = pd.DataFrame(cursor.fetchall(), columns=self.columns)
        display(result)

        # Display the menu options again
        display(self.menu_options, self.exit_button)

    def exit_loop(self, btn):
        clear_output(wait=True)
        print("Exiting the loop...")

# Connect to the SQLite database
conn = sqlite3.connect('/content/drive/MyDrive/DB/db.db')

# Instantiate the QueryExecutor class
query_executor = QueryExecutor(conn)

# Display the buttons after initializing the class
display(query_executor.first_name_input, query_executor.last_name_input, query_executor.date_input, query_executor.submit_button)
# Out:
# Dropdown(description='Select Option:', options=('Select optn', 'Display Booking Details', 'Display Trains on S…
# Button(description='Exit', style=ButtonStyle())
# Text(value='', description='First Name:')
# Text(value='', description='Last Name:')
# Text(value='', description='Date (YYYY-MM-DD):')
# Button(description='Submit', style=ButtonStyle())
# Text(value='', description='First Name:')
# Text(value='', description='Last Name:')
# Button(description='Submit', style=ButtonStyle())
#          Train Name  Train Number     Status Train Date
# 0  Flying Scottsman             2  Edinburgh     London
# 1    Golden Chariot             4  Bangalore        Goa
# Dropdown(description='Select Option:', index=1, options=('Select optn', 'Display Booking Details', 'Display Tr…
# Button(description='Exit', style=ButtonStyle())
# Text(value='', description='Date (YYYY-MM-DD):')
# Button(description='Submit', style=ButtonStyle())
#   First Name Last Name    Train Name  Train Number  Status
# ...

# %% [markdown]
# After Query 4:

# %%
import sqlite3
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, clear_output

class QueryExecutor:
    def __init__(self, conn):
        self.conn = conn
        self.options_dict = {
            'Select optn': '''
            ''',
            'Display Booking Details': '''
                SELECT T.TrainName, T.TrainNumber, T.SourceStation, T.DestinationStation
                FROM Train as T
                JOIN Booked as B ON T.TrainNumber = B.Train_Number
                JOIN Passenger as P ON B.Passanger_ssn = P.SSN
                WHERE P.first_name=? AND P.last_name=?;
            ''',
            'Display Trains on Selected Date': '''
                SELECT P.first_name, P.last_name, T.TrainName, T.TrainNumber, B.Status
                FROM Train as T
                JOIN Booked as B ON T.TrainNumber = B.Train_Number
                JOIN Passenger as P ON B.Passanger_ssn = P.SSN
                JOIN Train_Status as TS ON TS.TrainName = T.TrainName
                WHERE TS.TrainDate=? AND B.Status = "Booked";
            ''',
            'Train Details': '''
                select all T.TrainName, T.TrainNumber, T.SourceStation, T.DestinationStation , count(B.Passanger_ssn)
                FROM Train as T,
                Booked as B
                WHERE T.TrainNumber = B.Train_Number
                GROUP by T.TrainName ;
            '''
            # Add other queries as needed
        }

        self.menu_options = widgets.Dropdown(
            options=list(self.options_dict.keys()),
            value='Select optn',
            description='Select Option:'
        )

        self.exit_button = widgets.Button(description='Exit')

        self.menu_options.observe(self.on_option_selected, names='value')
        self.exit_button.on_click(self.exit_loop)

        # Initialize input widgets
        self.first_name_input = widgets.Text(description='First Name:')
        self.last_name_input = widgets.Text(description='Last Name:')
        self.date_input = widgets.Text(description='Date (YYYY-MM-DD):')
        self.submit_button = widgets.Button(description="Submit")
        self.submit_button.on_click(self.on_submit_inputs)

        # Display the initial widgets
        display(self.menu_options, self.exit_button)

    def on_option_selected(self, change):
        selected_option = change['new']

        if selected_option == 'Display Booking Details':
            display(self.first_name_input, self.last_name_input, self.submit_button)
        elif selected_option == 'Display Trains on Selected Date':
            display(self.date_input, self.submit_button)
        elif selected_option == 'Select optn':
            pass
        elif selected_option == 'Train Details':
            display(self.submit_button)

    def on_submit_inputs(self, btn):
        selected_option = self.menu_options.value
        query = self.options_dict.get(selected_option, 'SELECT * FROM Train;')  # Default query if option not found

        # Execute the query based on the selected option
        cursor = self.conn.cursor()

        if selected_option == 'Display Booking Details':
            self.columns = ['Train Name', 'Train Number', 'Status', 'Train Date']
            cursor.execute(query, (self.first_name_input.value, self.last_name_input.value))
        elif selected_option == 'Display Trains on Selected Date':
            self.columns = ['First Name', 'Last Name', 'Train Name', 'Train Number', 'Status']
            cursor.execute(query, (self.date_input.value,))
        elif selected_option == 'Train Details':
            self.columns = ['Train Name', 'Train Number', 'Source', 'Destination', 'Count of Passengers']
            cursor.execute(query)

        # Display the result
        result = pd.DataFrame(cursor.fetchall(), columns=self.columns)
        display(result)

        # Display the menu options again
        display(self.menu_options, self.exit_button)

    def exit_loop(self, btn):
        clear_output(wait=True)
        print("Exiting the loop...")

# Connect to the SQLite database
conn = sqlite3.connect('/content/drive/MyDrive/DB/db.db')

# Instantiate the QueryExecutor class
query_executor = QueryExecutor(conn)

# Display the buttons after initializing the class
display(query_executor.first_name_input, query_executor.last_name_input, query_executor.date_input, query_executor.submit_button)
# Out:
# Dropdown(description='Select Option:', options=('Select optn', 'Display Booking Details', 'Display Trains on S…
# Button(description='Exit', style=ButtonStyle())
# Text(value='', description='First Name:')
# Text(value='', description='Last Name:')
# Text(value='', description='Date (YYYY-MM-DD):')
# Button(description='Submit', style=ButtonStyle())
# Text(value='', description='First Name:')
# Text(value='', description='Last Name:')
# Button(description='Submit', style=ButtonStyle())
#          Train Name  Train Number     Status Train Date
# 0  Flying Scottsman             2  Edinburgh     London
# 1    Golden Chariot             4  Bangalore        Goa
# Dropdown(description='Select Option:', index=1, options=('Select optn', 'Display Booking Details', 'Display Tr…
# Button(description='Exit', style=ButtonStyle())
# Text(value='', description='Date (YYYY-MM-DD):')
# Button(description='Submit', style=ButtonStyle())
# ...

# %% [markdown]
# After Q5:

# %%
import sqlite3
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, clear_output

class QueryExecutor:
    def __init__(self, conn):
        self.conn = conn
        self.options_dict = {
            'Select optn': '''
            ''',
            'Display Booking Details': '''
                SELECT T.TrainName, T.TrainNumber, T.SourceStation, T.DestinationStation
                FROM Train as T
                JOIN Booked as B ON T.TrainNumber = B.Train_Number
                JOIN Passenger as P ON B.Passanger_ssn = P.SSN
                WHERE P.first_name=? AND P.last_name=?;
            ''',
            'Display Trains on Selected Date': '''
                SELECT P.first_name, P.last_name, T.TrainName, T.TrainNumber, B.Status
                FROM Train as T
                JOIN Booked as B ON T.TrainNumber = B.Train_Number
                JOIN Passenger as P ON B.Passanger_ssn = P.SSN
                JOIN Train_Status as TS ON TS.TrainName = T.TrainName
                WHERE TS.TrainDate=? AND B.Status = "Booked";
            ''',
            'Train Details': '''
                select all T.TrainName, T.TrainNumber, T.SourceStation, T.DestinationStation , count(B.Passanger_ssn)
                FROM Train as T,
                Booked as B
                WHERE T.TrainNumber = B.Train_Number
                GROUP by T.TrainName ;
            ''',
            'Train and Confirmed Passenger Details': '''
                select P.first_name, P.last_name, P.SSN, T.TrainName, T.TrainNumber FROM Train as T JOIN
                Booked as B on T.TrainNumber = B.Train_Number JOIN
                Passenger as P on B.Passanger_ssn = P.SSN
                where T.TrainName=? and B.Status='Booked';
            '''
            # Add other queries as needed
        }

        self.menu_options = widgets.Dropdown(
            options=list(self.options_dict.keys()),
            value='Select optn',
            description='Select Option:'
        )

        self.exit_button = widgets.Button(description='Exit')

        self.menu_options.observe(self.on_option_selected, names='value')
        self.exit_button.on_click(self.exit_loop)

        # Initialize input widgets
        self.first_name_input = widgets.Text(description='First Name:')
        self.last_name_input = widgets.Text(description='Last Name:')
        self.date_input = widgets.Text(description='Date (YYYY-MM-DD):')
        self.train_input = widgets.Text(description="Train Name:")
        self.submit_button = widgets.Button(description="Submit")
        self.submit_button.on_click(self.on_submit_inputs)

        # Display the initial widgets
        display(self.menu_options, self.exit_button)

    def on_option_selected(self, change):
        selected_option = change['new']

        if selected_option == 'Display Booking Details':
            display(self.first_name_input, self.last_name_input, self.submit_button)
        elif selected_option == 'Display Trains on Selected Date':
            display(self.date_input, self.submit_button)
        elif selected_option == 'Train Details':
            display(self.submit_button)
        elif selected_option == 'Train and Confirmed Passenger Details':
            display(self.train_input, self.submit_button)
        elif selected_option == 'Select optn':
            pass


    def on_submit_inputs(self, btn):
        selected_option = self.menu_options.value
        query = self.options_dict.get(selected_option, 'SELECT * FROM Train;')  # Default query if option not found

        # Execute the query based on the selected option
        cursor = self.conn.cursor()

        if selected_option == 'Display Booking Details':
            self.columns = ['Train Name', 'Train Number', 'Status', 'Train Date']
            cursor.execute(query, (self.first_name_input.value, self.last_name_input.value))
        elif selected_option == 'Display Trains on Selected Date':
            self.columns = ['First Name', 'Last Name', 'Train Name', 'Train Number', 'Status']
            cursor.execute(query, (self.date_input.value,))
        elif selected_option == 'Train Details':
            self.columns = ['Train Name', 'Train Number', 'Source', 'Destination', 'Count of Passengers']
            cursor.execute(query)
        elif selected_option == 'Train and Confirmed Passenger Details':
            self.columns = ['First Name', 'Last Name', 'SSN', 'Train Name', 'Train Number']
            cursor.execute(query, (self.train_input.value,))

        # Display the result
        result = pd.DataFrame(cursor.fetchall(), columns=self.columns)
        display(result)
        selected_option = 'Select optn'
        # Display the menu options again
        display(self.menu_options, self.exit_button)

    def exit_loop(self, btn):
        clear_output(wait=True)
        print("Exiting the loop...")

# Connect to the SQLite database
conn = sqlite3.connect('/content/drive/MyDrive/DB/db.db')

# Instantiate the QueryExecutor class
query_executor = QueryExecutor(conn)

# Display the buttons after initializing the class
display(query_executor.menu_options, query_executor.submit_button)
# Out:
# Dropdown(description='Select Option:', options=('Select optn', 'Display Booking Details', 'Display Trains on S…
# Button(description='Exit', style=ButtonStyle())
# Dropdown(description='Select Option:', options=('Select optn', 'Display Booking Details', 'Display Trains on S…
# Button(description='Submit', style=ButtonStyle())
# Text(value='', description='First Name:')
# Text(value='', description='Last Name:')
# Button(description='Submit', style=ButtonStyle())
#          Train Name  Train Number     Status Train Date
# 0  Flying Scottsman             2  Edinburgh     London
# 1    Golden Chariot             4  Bangalore        Goa
# Dropdown(description='Select Option:', index=1, options=('Select optn', 'Display Booking Details', 'Display Tr…
# Button(description='Exit', style=ButtonStyle())
